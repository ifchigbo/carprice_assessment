# %%
import pandas as pd

# %%
df = pd.read_csv("CarPrice.csv")

# %%
df.head()
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero Quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype  cylindernumber  enginesize fuelsystem  horsepower  \
# ...

# %%
df.loc[df['ca
# Out:
#     car_ID       CarName fueltype  doornumber carbody drivewheel  \
# 89      90  Nissan versa      gas           2   sedan        fwd
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 89          front       94.5      165.3      63.8       54.5        1889
#
#    enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# 89        ohc               4          97       2bbl          69       31
#
#     highwaympg  price
# 89          37   5499

# %%
df.tail(5)
# Out:
#      car_ID          CarName fueltype  doornumber carbody drivewheel  \
# 200     201  volvo 145e (sw)      gas           4   sedan        rwd
# 201     202      volvo 144ea      gas           4   sedan        rwd
# 202     203      volvo 244dl      gas           4   sedan        rwd
# 203     204        volvo 246   diesel           4   sedan        rwd
# 204     205      volvo 264gl      gas           4   sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 200          front      109.1      188.8      68.9       55.5        2952
# 201          front      109.1      188.8      68.8       55.5        3049
# 202          front      109.1      188.8      68.9       55.5        3012
# 203          front      109.1      188.8      68.9       55.5        3217
# 204          front      109.1      188.8      68.9       55.5        3062
#
#     enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# ...

# %%
df.loc[df['cylindernumber'] == 6]
# Out:
#      car_ID                   CarName fueltype  doornumber      carbody  \
# 2         3  alfa-romero Quadrifoglio      gas           2    hatchback
# 12       13                    bmw x1      gas           2        sedan
# 13       14                    bmw x3      gas           4        sedan
# 14       15                    bmw z4      gas           4        sedan
# 15       16                    bmw x4      gas           4        sedan
# 16       17                    bmw x5      gas           2        sedan
# 17       18                    bmw x3      gas           4        sedan
# 47       48                 jaguar xj      gas           4        sedan
# 48       49                 jaguar xf      gas           4        sedan
# 101     102               nissan dayz      gas           4        sedan
# 102     103               nissan fuga      gas           4        wagon
# 103     104               nissan otti      gas           4        sedan
# ...

# %%
df.loc[df['carbody'] == 'wagon']
# Out:
#      car_ID                    CarName fueltype  doornumber carbody  \
# 7         8                  audi 5000      gas           4   wagon
# 28       29          dodge dart custom      gas           4   wagon
# 36       37        honda civic 1500 gl      gas           4   wagon
# 68       69   buick century luxus (sw)   diesel           4   wagon
# 93       94               nissan titan      gas           4   wagon
# 97       98                nissan note      gas           4   wagon
# 102     103                nissan fuga      gas           4   wagon
# 109     110           peugeot 504 (sw)      gas           4   wagon
# 110     111                peugeot 504   diesel           4   wagon
# 113     114                peugeot 504      gas           4   wagon
# 114     115  peugeot 505s turbo diesel   diesel           4   wagon
# 123     124           plymouth valiant      gas           4   wagon
# 130     131               renault 12tl      gas           4   wagon
# ...

# %%
convertible = df.loc[df['carbody'] == 'convertible']

# %%
convertible.price.sum()
# Out:
# 131343

# %%
hatchback = df.loc[df['carbody'] == 'hatchback']

# %%
hatchback.price.sum()
# Out:
# 726365

# %%
df.loc[df['carbody'] == 'hardtop'].sum()['price']
# Out:
# 177668
