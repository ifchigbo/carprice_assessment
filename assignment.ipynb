# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CarPrice.csv')

# %%
df.head(10)
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero Quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
# 5       6                  audi fox      gas           2        sedan
# 6       7                audi 100ls      gas           4        sedan
# 7       8                 audi 5000      gas           4        wagon
# 8       9                 audi 4000      gas           4        sedan
# 9      10       audi 5000s (diesel)      gas           2    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# ...

# %%
df['CarName'] = df['CarName'].str.lower()

# %%
df.sort_values(by=['CarName'])
# Out:
#      car_ID                   CarName fueltype  doornumber      carbody  \
# 0         1        alfa-romero giulia      gas           2  convertible
# 2         3  alfa-romero quadrifoglio      gas           2    hatchback
# 1         2       alfa-romero stelvio      gas           2  convertible
# 3         4               audi 100 ls      gas           4        sedan
# 4         5                audi 100ls      gas           4        sedan
# ..      ...                       ...      ...         ...          ...
# 198     199               volvo 264gl      gas           4        sedan
# 204     205               volvo 264gl      gas           4        sedan
# 199     200              volvo diesel      gas           4        wagon
# 189     190                 vw dasher      gas           2  convertible
# 190     191                 vw rabbit      gas           2    hatchback
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# ...

# %%
df.loc[df['car_ID'] == 98]
# Out:
#     car_ID      CarName fueltype  doornumber carbody drivewheel  \
# 97      98  nissan note      gas           4   wagon        fwd
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 97          front       94.5      170.2      63.8       53.5        2037
#
#    enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# 97        ohc               4          97       2bbl          69       31
#
#     highwaympg  price
# 97          37   7999

# %%
df.loc[df['CarName'] == 'nissan note']
# Out:
#     car_ID      CarName fueltype  doornumber carbody drivewheel  \
# 97      98  nissan note      gas           4   wagon        fwd
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 97          front       94.5      170.2      63.8       53.5        2037
#
#    enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# 97        ohc               4          97       2bbl          69       31
#
#     highwaympg  price
# 97          37   7999

# %%
df.head(10)
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
# 5       6                  audi fox      gas           2        sedan
# 6       7                audi 100ls      gas           4        sedan
# 7       8                 audi 5000      gas           4        wagon
# 8       9                 audi 4000      gas           4        sedan
# 9      10       audi 5000s (diesel)      gas           2    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# ...

# %%
body_type_car = df['carbody'].values
renewed_body = set(body_type_car)

# %%
print(renewed_body)
# Out:
# {'wagon', 'sedan', 'convertible', 'hardtop', 'hatchback'}

# %%
mywagon = df.loc[df['carbody'] == 'convertible']

# %%
mywagon.price.sum()
# Out:
# 131343

# %%
['sedan', 'hardtop', 'wagon', 'hatchback', 'convertible']
# Out:
# ['sedan', 'hardtop', 'wagon', 'hatchback', 'convertible']

# %%
df.price.max( )
# Out:
# 45400

# %%
len(df.columns)
# Out:
# 20

# %%
df.head(10)
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
# 5       6                  audi fox      gas           2        sedan
# 6       7                audi 100ls      gas           4        sedan
# 7       8                 audi 5000      gas           4        wagon
# 8       9                 audi 4000      gas           4        sedan
# 9      10       audi 5000s (diesel)      gas           2    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# ...

# %%
df.CarName
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
df
# Out:
#      car_ID                   CarName fueltype  doornumber      carbody  \
# 0         1        alfa-romero giulia      gas           2  convertible
# 1         2       alfa-romero stelvio      gas           2  convertible
# 2         3  alfa-romero quadrifoglio      gas           2    hatchback
# 3         4               audi 100 ls      gas           4        sedan
# 4         5                audi 100ls      gas           4        sedan
# ..      ...                       ...      ...         ...          ...
# 200     201           volvo 145e (sw)      gas           4        sedan
# 201     202               volvo 144ea      gas           4        sedan
# 202     203               volvo 244dl      gas           4        sedan
# 203     204                 volvo 246   diesel           4        sedan
# 204     205               volvo 264gl      gas           4        sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# ...

# %%
list_me = [2, 3, 4]
my_col_list = list(df.columns)
index = 0 
ans = []
for items in range(len(my_col_list)):
    if items in list_me:
        ans.append(my_col_list[items])
    #print(items,":",my_col_list[items])
print(ans)
# Out:
# ['fueltype', 'doornumber', 'carbody']

# %%
ans + ['hello']
# Out:
# ['fueltype', 'doornumber', 'carbody', 'hello']

# %%
ans
# Out:
# ['fueltype', 'doornumber', 'carbody']

# %%
ans = ans + ['hello']

# %%
ans
# Out:
# ['fueltype', 'doornumber', 'carbody', 'hello']

# %%
fuel_system = df['fuelsystem']
new_fule = list(set(fuel_system))
new_fule
# Out:
# ['idi', 'spfi', '4bbl', 'mfi', 'mpfi', 'spdi', '2bbl', '1bbl']

# %%
df.head(10)
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
# 5       6                  audi fox      gas           2        sedan
# 6       7                audi 100ls      gas           4        sedan
# 7       8                 audi 5000      gas           4        wagon
# 8       9                 audi 4000      gas           4        sedan
# 9      10       audi 5000s (diesel)      gas           2    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# ...

# %%
fuel_system_count = df.groupby(by='fuelsystem')['car_ID'].count()

# %%
type(fuel_system_count)
# Out:
# pandas.core.series.Series

# %%
cart = pd.DataFrame(fuel_system_count).reset_index()

# %%
cart.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cart.reset_index(drop=True)
# Out:
#   fuelsystem  car_ID
# 0       1bbl      11
# 1       2bbl      66
# 2       4bbl       3
# 3        idi      20
# 4        mfi       1
# 5       mpfi      94
# 6       spdi       9
# 7       spfi       1

# %%
fuel=[]
id=[]

for x in cart['fuelsystem']:
    fuel.append(x)

for y in cart['car_ID']:
    id.append(y)

# %%
from matplotlib import pyplot as plt
plt.bar(fuel, id)
plt.show()

# %%
df.columns
# Out:
# Index(['car_ID', 'CarName', 'fueltype', 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'horsepower', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.sort_values(by='horsepower')
# Out:
#      car_ID               CarName fueltype  doornumber      carbody  \
# 18       19      chevrolet impala      gas           2    hatchback
# 182     183      vokswagen rabbit   diesel           2        sedan
# 184     185  volkswagen model 111   diesel           4        sedan
# 90       91           nissan gt-r   diesel           2        sedan
# 158     159         toyota corona   diesel           4        sedan
# ..      ...                   ...      ...         ...          ...
# 127     128       porsche cayenne      gas           2      hardtop
# 128     129        porsche boxter      gas           2  convertible
# 126     127     porcshce panamera      gas           2      hardtop
# 49       50             jaguar xk      gas           2        sedan
# 129     130       porsche cayenne      gas           2    hatchback
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 18         fwd          front       88.4      141.1      60.3       53.2
# ...

# %%
df.loc[df.horsepower == 52]
# Out:
#      car_ID               CarName fueltype  doornumber carbody drivewheel  \
# 182     183      vokswagen rabbit   diesel           2   sedan        fwd
# 184     185  volkswagen model 111   diesel           4   sedan        fwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 182          front       97.3      171.7      65.5       55.7        2261
# 184          front       97.3      171.7      65.5       55.7        2264
#
#     enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# 182        ohc               4          97        idi          52       37
# 184        ohc               4          97        idi          52       37
#
#      highwaympg  price
# 182          46   7775
# 184          46   7995

# %%
df
# Out:
#      car_ID                   CarName fueltype  doornumber      carbody  \
# 0         1        alfa-romero giulia      gas           2  convertible
# 1         2       alfa-romero stelvio      gas           2  convertible
# 2         3  alfa-romero quadrifoglio      gas           2    hatchback
# 3         4               audi 100 ls      gas           4        sedan
# 4         5                audi 100ls      gas           4        sedan
# ..      ...                       ...      ...         ...          ...
# 200     201           volvo 145e (sw)      gas           4        sedan
# 201     202               volvo 144ea      gas           4        sedan
# 202     203               volvo 244dl      gas           4        sedan
# 203     204                 volvo 246   diesel           4        sedan
# 204     205               volvo 264gl      gas           4        sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# ...

# %%
df['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
mydf.loc[0:50,"salary"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ichigbo/Documents/dataML_data_science/MLseries/Carprice_Assesment/assignment.ipynb Cell 38 in <module>
# ----> <a href='vscode-notebook-cell:/Users/ichigbo/Documents/dataML_data_science/MLseries/Carprice_Assesment/assignment.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> mydf.loc[0:50,"salary"].mean()
#
# NameError: name 'mydf' is not defined

# %%
df.head(10)
