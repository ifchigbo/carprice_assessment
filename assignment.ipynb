# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CarPrice.csv')

# %%
df.head(10)
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero Quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
# 5       6                  audi fox      gas           2        sedan
# 6       7                audi 100ls      gas           4        sedan
# 7       8                 audi 5000      gas           4        wagon
# 8       9                 audi 4000      gas           4        sedan
# 9      10       audi 5000s (diesel)      gas           2    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# ...

# %%
df.loc[df['car_ID'] == 8]
# Out:
#    car_ID    CarName fueltype  doornumber carbody drivewheel enginelocation  \
# 7       8  audi 5000      gas           4   wagon        fwd          front
#
#    wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# 7      105.8      192.7      71.4       55.7        2954        ohc
#
#    cylindernumber  enginesize fuelsystem  horsepower  citympg  highwaympg  \
# 7               5         136       mpfi         110       19          25
#
#    price
# 7  18920

# %%
def cyclinders():
    cy = df['cylindernumber'].values
    return cy 
all_cylinders = []
for items in cyclinders():
    all_cylinders.append(items)
print(set(all_cylinders))
# Out:
# {2, 3, 4, 5, 6, 8, 12}

# %%
#df.loc[df['cylindernumber'] == 8]

for items in set(df['cylindernumber']):
    print(items)
# Out:
# 2
# 3
# 4
# 5
# 6
# 8
# 12

# %%
values = np.array(df.columns)

count = 0 
for i in values:
    if count < len(values):
        print ("{} : {}".format(count, i))
    count +=1
# Out:
# 0 : car_ID
# 1 : CarName
# 2 : fueltype
# 3 : doornumber
# 4 : carbody
# 5 : drivewheel
# 6 : enginelocation
# 7 : wheelbase
# 8 : carlength
# 9 : carwidth
# 10 : carheight
# 11 : curbweight
# 12 : enginetype
# 13 : cylindernumber
# 14 : enginesize
# 15 : fuelsystem
# 16 : horsepower
# 17 : citympg
# 18 : highwaympg
# 19 : price

# %%
#df.loc[df['carbody']]
body_types = df['carbody'].values
set(body_types)
# Out:
# {'convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'}

# %%
df.loc[df['carbody'] == 'wagon']
# Out:
#      car_ID                    CarName fueltype  doornumber carbody  \
# 7         8                  audi 5000      gas           4   wagon
# 28       29          dodge dart custom      gas           4   wagon
# 36       37        honda civic 1500 gl      gas           4   wagon
# 68       69   buick century luxus (sw)   diesel           4   wagon
# 93       94               nissan titan      gas           4   wagon
# 97       98                nissan note      gas           4   wagon
# 102     103                nissan fuga      gas           4   wagon
# 109     110           peugeot 504 (sw)      gas           4   wagon
# 110     111                peugeot 504   diesel           4   wagon
# 113     114                peugeot 504      gas           4   wagon
# 114     115  peugeot 505s turbo diesel   diesel           4   wagon
# 123     124           plymouth valiant      gas           4   wagon
# 130     131               renault 12tl      gas           4   wagon
# ...

# %%
df_2 = df[["car_ID","CarName","fueltype"]]

# %%
df_2
# Out:
#      car_ID                   CarName fueltype
# 0         1        alfa-romero giulia      gas
# 1         2       alfa-romero stelvio      gas
# 2         3  alfa-romero Quadrifoglio      gas
# 3         4               audi 100 ls      gas
# 4         5                audi 100ls      gas
# ..      ...                       ...      ...
# 200     201           volvo 145e (sw)      gas
# 201     202               volvo 144ea      gas
# 202     203               volvo 244dl      gas
# 203     204                 volvo 246   diesel
# 204     205               volvo 264gl      gas
#
# [205 rows x 3 columns]

# %%
from getDatPDDF import getCarasPDDF, getDataColumns

df = getCarasPDDF()
col = getDataColumns()
df[col[0]]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 200    201
# 201    202
# 202    203
# 203    204
# 204    205
# Name: car_ID, Length: 205, dtype: int64

# %%
df.loc[df['car_ID'] == 45]
# Out:
#     car_ID       CarName fueltype  doornumber carbody drivewheel  \
# 44      45  isuzu D-Max       gas           2   sedan        fwd
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 44          front       94.5      155.9      63.6       52.0        1874
#
#    enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# 44        ohc               4          90       2bbl          70       38
#
#     highwaympg  price
# 44          43   8916
